].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # 주문금액의 평균을 알고싶어..
# ----> 2 df['주문금액'].mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6473     # GH#47500 - change to TypeError to match other methods
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1698 elif not (is_float(x) or is_integer(x) or is_complex(x)):
#    1699     if isinstance(x, str):
#    1700         # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701         raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702     try:
#    1703         x = float(x)
#
# TypeError: Could not convert string '12,0008,50015,0003,00010,0007,00012,0008,50015,0003,00010,0007,00012,0008,50015,0003,00010,00012,0008,50015,0003,00010,0007,00012,0008,50015,0003,00012,0008,50015,0003,00010,0007,00012,0008,50015,0003,00010,00012,0008,50015,0003,00010,0007,00012,0008,50015,0003,00010,00012,0008,50015,0003,00010,0007,00012,0008,50015,0003,00010,000' to numeric

# %%
# 주문금액은 숫자처럼 보이지만.. 숫자데이터 아님.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   주문번호    60 non-null     int64
#  1   회원ID    60 non-null     object
#  2   주문금액    60 non-null     object
#  3   주문일자    60 non-null     object
#  4   결제수단    60 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.5+ KB

# %%
# 자료형 변환 astype() -- 숫자 사이에 , 가 있어서 그냥은 못바꿈.
df['주문금액']=df['주문금액'].str.replace(',','').astype(int) #or 'int64'
df['주문금액'].mean()
# Out:
# np.float64(9425.0)

# %%
# 주문일자중 2월 주문내역만 추출...
# 문자열에서 2월 데이터 추출이 불편함.
df['주문일자']=pd.to_datetime(df['주문일자'])
df.dtypes
# Out:
# 주문번호             int64
# 회원ID            object
# 주문금액             int64
# 주문일자    datetime64[ns]
# 결제수단            object
# dtype: object

# %%
# 2월 데이터만 추출
df[  df['주문일자'].dt.month == 2  ]
# Out:
#     주문번호  회원ID   주문금액       주문일자  결제수단
# 3  10004  u004   3000 2023-02-02    카드
# 4  10005  u001  10000 2023-02-06  계좌이체
# 5  10006  u002   7000 2023-02-14    카드
# 6  10007  u003  12000 2023-02-26    카드

# %%
# 연월 까지 모두 필터링 2023년 4월
df[ (df['주문일자'].dt.year==2023) & (df['주문일자'].dt.month==4)  ]
# Out:
#      주문번호  회원ID   주문금액       주문일자  결제수단
# 11  10012  u001   7000 2023-04-02    카드
# 12  10013  u002  12000 2023-04-06    카드
# 13  10014  u003   8500 2023-04-14    카드
# 14  10015  u004  15000 2023-04-18    현금
# 15  10016  u001   3000 2023-04-25    카드
# 16  10017  u002  10000 2023-04-29  계좌이체

# %%
# 위 and 연산을 보다 쉽게..하기위해 날짜를 인덱스로 사용
df.set_index('주문일자').loc['2023-06'] #인덱스명이 일치하지 않아도 됨.
# Out:
#              주문번호  회원ID   주문금액  결제수단
# 주문일자
# 2023-06-02  10022  u001  10000  계좌이체
# 2023-06-07  10023  u002   7000    카드
# 2023-06-13  10024  u003  12000    카드
# 2023-06-18  10025  u004   8500    카드
# 2023-06-24  10026  u001  15000    현금
# 2023-06-29  10027  u002   3000    카드

# %%
#결제수단 데이터 유형
df['결제수단'].value_counts() #각 값들의 개수
# Out:
# 결제수단
# 카드      39
# 현금      11
# 계좌이체    10
# Name: count, dtype: int64

# %%
# 결제수단 처럼 정해져 있는 값을가진 데이터의 유형을 범주형이라고 부름
df['결제수단'].dtype
# Out:
# dtype('O')

# %%
# 문자열로 되어 있음.. 메모리를 조금 효율적으로 하고 싶다면..
# 범주형의 자료형을  object --> category
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   주문번호    60 non-null     int64
#  1   회원ID    60 non-null     object
#  2   주문금액    60 non-null     int64
#  3   주문일자    60 non-null     datetime64[ns]
#  4   결제수단    60 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 2